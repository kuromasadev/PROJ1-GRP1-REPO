# %%
import pandas as pd
import json
import requests
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %%
from config import geoapify_key

# %%
df = pd.read_csv("/Users/ali/1st-group-project/Resources/yelp_locations_df_v01.csv")

df.head()
# Out:
#    MTSW4McQd7CbVtyjqoe9mw St Honore Pastries         935 Race St  \
# 0  MUTTqe8uqyMdBl186RmNeA           Tuna Bar         205 Race St
# 1  ROeacJQwBeh05Rqg7F6TCg                BAP       1224 South St
# 2  QdN72BWoyFypdGJhhI5r7g            Bar One        767 S 9th St
# 3  Mjboz24M9NlBeiOJKLEd_Q   DeSandro on Main        4105 Main St
# 4  aPNXGTDkf-4bjhyMBQxqpQ         Craft Hall  901 N Delaware Ave
#
#    Philadelphia  PA    19107  39.9555052  -75.1555641  4.0   80  1  \
# 0  Philadelphia  PA  19106.0   39.953949   -75.143226  4.0  245  1
# 1  Philadelphia  PA  19147.0   39.943223   -75.162568  4.5  205  1
# 2  Philadelphia  PA  19147.0   39.939825   -75.157447  4.0   65  0
# 3  Philadelphia  PA  19127.0   40.022466   -75.218314  3.0   41  0
# 4  Philadelphia  PA  19123.0   39.962582   -75.135657  3.5   65  1
#
#   {'RestaurantsDelivery': 'False', 'OutdoorSeating': 'False', 'BusinessAcceptsCreditCards': 'False', 'BusinessParking': "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}", 'BikeParking': 'True', 'RestaurantsPriceRange2': '1', 'RestaurantsTakeOut': 'True', 'ByAppointmentOnly': 'False', 'WiFi': "u'free'", 'Alcohol': "u'none'", 'Caters': 'True'}  \
# 0  {'RestaurantsReservations': 'True', 'Restauran...
# 1  {'NoiseLevel': "u'quiet'", 'GoodForMeal': "{'d...
# 2  {'Smoking': "u'no'", 'NoiseLevel': "u'average'...
# 3  {'RestaurantsReservations': 'False', 'Caters':...
# 4  {'OutdoorSeating': 'True', 'RestaurantsPriceRa...
#
#   Restaurants, Food, Bubble Tea, Coffee & Tea, Bakeries  \
# 0                  Sushi Bars, Restaurants, Japanese
# 1                                Korean, Restaurants
# 2  Cocktail Bars, Bars, Italian, Nightlife, Resta...
# 3                    Pizza, Restaurants, Salad, Soup
# 4  Eatertainment, Arts & Entertainment, Brewpubs,...
#
#   {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', 'Wednesday': '7:0-20:0', 'Thursday': '7:0-20:0', 'Friday': '7:0-21:0', 'Saturday': '7:0-21:0', 'Sunday': '7:0-21:0'}
# 0  {'Tuesday': '13:30-22:0', 'Wednesday': '13:30-...
# 1  {'Monday': '11:30-20:30', 'Tuesday': '11:30-20...
# 2  {'Monday': '16:0-0:0', 'Tuesday': '16:0-0:0', ...
# 3  {'Tuesday': '17:0-21:30', 'Wednesday': '17:0-1...
# 4  {'Monday': '0:0-0:0', 'Wednesday': '16:0-22:0'...

# %%
target_city = "Philadelphia, Pennsylvania"

target_url = f"https://api.geoapify.com/v2/places?categories=catering&filter=place:51d80144b194c852c0590b89d6a9f9004440f00101f90176de020000000000c0020692030c5068696c6164656c70686961&limit=20&apiKey={geoapify_key}"

# %%
df.shape
# Out:
# (14568, 14)

# %%
target_url
# Out:
# 'https://api.geoapify.com/v2/places?categories=catering&filter=place:51d80144b194c852c0590b89d6a9f9004440f00101f90176de020000000000c0020692030c5068696c6164656c70686961&limit=20&apiKey=eca355bfb1ab429485ba24bbe352036e'

# %%
geo_data = requests.get(target_url).json()

print(geo_data)
# Out:
# {'type': 'FeatureCollection', 'features': [{'type': 'Feature', 'properties': {'name': 'Valley Green Inn', 'country': 'United States', 'country_code': 'us', 'state': 'Pennsylvania', 'county': 'Philadelphia County', 'city': 'Philadelphia', 'postcode': '19128', 'street': 'Valley Green Road', 'lon': -75.21821459327312, 'lat': 40.05408665, 'state_code': 'PA', 'formatted': 'Valley Green Inn, Valley Green Road, Philadelphia, PA 19128, United States of America', 'address_line1': 'Valley Green Inn', 'address_line2': 'Valley Green Road, Philadelphia, PA 19128, United States of America', 'categories': ['building', 'building.catering', 'building.historic', 'catering', 'catering.restaurant', 'catering.restaurant.american', 'tourism', 'tourism.sights', 'vegan', 'vegetarian'], 'details': ['details', 'details.catering', 'details.contact', 'details.wiki_and_media'], 'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database Licence', 'url': 'https://www.openstreetmap.org/copyright', 'raw': {'name': 'Valley Green Inn', 'phone': '+1-215-247-1730', 'osm_id': 52495244, 'amenity': 'restaurant', 'cuisine': 'american', 'website': 'http://www.valleygreeninn.com', 'building': 'yes', 'historic': 'building', 'osm_type': 'w', 'wikidata': 'Q78827991', 'addr:city': 'Philadelphia', 'addr:state': 'PA', 'diet:vegan': 'yes', 'addr:street': 'Valley Green Road', 'addr:postcode': 19128, 'opening_hours': 'Mo-Fr 12:00-16:00; Sa 11:00-16:00; Mo-Th 17:00-21:00; Fr-Sa 17:00-22:00; Su 10:00-15:00', 'addr:housename': 'Valley Green Inn', 'diet:vegetarian': 'yes', 'diet:pescetarian': 'yes'}}, 'place_id': '51339f9820f7cd52c0590510ea90ec064440f00102f9018c0321030000000092031056616c6c657920477265656e20496e6e'}, 'geometry': {'type': 'Point', 'coordinates': [-75.21820845512848, 40.054094423569076]}}, {'type': 'Feature', 'properties': {'name': "Geno's Steaks", 'country': 'United States', 'country_code': 'us', 'state': 'Pennsylvania', 'county': 'Philadelphia County', 'city': 'Philadelphia', 'postcode': '19147', 'district': 'Little Saigon', 'suburb': 'South Philadelphia', 'street': 'South 9th Street', 'housenumber': '1219', 'lon': -75.15883871303394, 'lat': 39.9338149, 'state_code': 'PA', 'formatted': "Geno's Steaks, 1219 South 9th Street, Philadelphia, PA 19147, United States of America", 'address_line1': "Geno's Steaks", 'address_line2': '1219 South 9th Street, Philadelphia, PA 19147, United States of America', 'categories': ['building', 'building.catering', 'catering', 'catering.restaurant'], 'details': ['details', 'details.catering', 'details.contact', 'details.wiki_and_media'], 'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database Licence', 'url': 'https://www.openstreetmap.org/copyright', 'raw': {'name': "Geno's Steaks", 'image': 'https://www.genosteaks.com/wp-content/uploads/2015/11/GenosLogo1.png', 'phone': '215-389-0659', 'osm_id': 334890731, 'amenity': 'restaurant', 'cuisine': 'steak_house;cheesesteak', 'website': 'https://www.genosteaks.com/', 'building': 'yes', 'osm_type': 'w', 'addr:city': 'Philadelphia', 'addr:state': 'PA', 'addr:street': 'S 9th St', 'description': 'The place with the BEST Cheesesteak in Philly, Geno’s was founded by one of Philly’s own, Joey Vento in 1966. The man had two boxes of steaks, a few hot dogs, and $6 in his pocket when he turned on the grills at 9th and Passyunk. Neighboring joints predic', 'addr:postcode': 19147, 'opening_hours': '24/7', 'addr:housenumber': 1219}}, 'place_id': '5129b60a1e2aca52c059c354125d88f74340f00102f901eb06f6130000000092030d47656e6f277320537465616b73'}, 'geometry': {'type': 'Point', 'coordinates': [-75.1588206390958, 39.93384898562501]}}, {'type': 'Feature', 'properties': {'name': "McDonald's", 'country': 'United States', 'country_code': 'us', 'state': 'Pennsylvania', 'county': 'Philadelphia County', 'city': 'Philadelphia', 'postcode': '19104', 'street': 'Walnut Street', 'housenumber': '3935', ' ...

# %%
print(json.dumps(geo_data, indent=4, sort_keys=True))
# Out:
# {
#     "features": [
#         {
#             "geometry": {
#                 "coordinates": [
#                     -75.21820845512848,
#                     40.054094423569076
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Valley Green Inn",
#                 "address_line2": "Valley Green Road, Philadelphia, PA 19128, United States of America",
#                 "categories": [
#                     "building",
#                     "building.catering",
#                     "building.historic",
#                     "catering",
#                     "catering.restaurant",
#                     "catering.restaurant.american",
#                     "tourism",
#                     "tourism.sights",
#                     "vegan",
#                     "vegetarian"
#                 ],
#                 "city": "Philadelphia",
#                 "country": "United States",
#                 "country_code": "us",
#                 "county": "Philadelphia County",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:city": "Philadelphia",
#                         "addr:housename": "Valley Green Inn",
#                         "addr:postcode": 19128,
#                         "addr:state": "PA",
#                         "addr:street": "Valley Green Road",
#                         "amenity": "restaurant",
#                         "building": "yes",
#                         "cuisine": "american",
#                         "diet:pescetarian": "yes",
#                         "diet:vegan": "yes",
#                         "diet:vegetarian": "yes",
#                         "historic": "building",
#                         "name": "Valley Green Inn",
#                         "opening_hours": "Mo-Fr 12:00-16:00; Sa 11:00-16:00; Mo-Th 17:00-21:00; Fr-Sa 17:00-22:00; Su 10:00-15:00",
#                         "osm_id": 52495244,
#                         "osm_type": "w",
#                         "phone": "+1-215-247-1730",
#                         "website": "http://www.valleygreeninn.com",
#                         "wikidata": "Q78827991"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.catering",
#                     "details.contact",
#                     "details.wiki_and_media"
#                 ],
#                 "formatted": "Valley Green Inn, Valley Green Road, Philadelphia, PA 19128, United States of America",
#                 "lat": 40.05408665,
#                 "lon": -75.21821459327312,
#                 "name": "Valley Green Inn",
#                 "place_id": "51339f9820f7cd52c0590510ea90ec064440f00102f9018c0321030000000092031056616c6c657920477265656e20496e6e",
#                 "postcode": "19128",
#                 "state": "Pennsylvania",
#                 "state_code": "PA",
#                 "street": "Valley Green Road"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -75.1588206390958,
#                     39.93384898562501
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Geno's Steaks",
#                 "address_line2": "1219 South 9th Street, Philadelphia, PA 19147, United States of America",
#                 "categories": [
#                     "building",
#                     "building.catering",
#                     "catering",
#                     "catering.restaurant"
#                 ],
#                 "city": "Philadelphia",
#                 "country": "United States",
#                 "country_code": "us",
#                 "county": "Philadelphia County",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:city": "Philadelphia",
#                         "addr:housenumber": 1219,
#                         "addr:postcode": 19147,
#                         "addr:state": "PA",
#                         "addr:street": "S 9th St",
#                         "amenity": "restaurant",
#                         "building": "yes",
#                         "cuisine": "steak_house;cheesesteak",
#                         "description": "The place with the BEST Cheesesteak in Philly, Geno\u2019s was founded by one of Philly\u2019s own, Joey Vento in 1966. The man had two boxes of steaks, a few hot dogs, and $6 in his pocket when he turned on the grills at 9th and Passyunk. Neighboring joints predic",
#                         "image": "https://www.genosteaks.com/wp-content/uploads/2015/11/GenosLogo1.png",
#                         "name": "Geno's Steaks",
#                         "opening_hours": "24/7",
#                         "osm_id": 334890731,
#                         "osm_type": "w",
#                         "phone": "215-389-0659",
#                         "website": "https://www.genosteaks.com/"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.catering",
#                     "details.contact",
#                     "details.wiki_and_media"
#                 ],
#                 "district": "Little Saigon",
#                 "formatted": "Geno's Steaks, 1219 South 9th Street, Philadelphia, PA 19147, United States of America",
#                 "housenumber": "1219",
#                 "lat": 39.9338149,
#                 "lon": -75.15883871303394,
#                 "name": "Geno's Steaks",
#                 "place_id": "5129b60a1e2aca52c059c354125d88f74340f00102f901eb06f6130000000092030d47656e6f277320537465616b73",
#                 "postcode": "19147",
#                 "state": "Pennsylvania",
#                 "state_code": "PA",
#                 "street": "South 9th Street",
#                 "suburb": "South Philadelphia"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -75.20233757794372,
#                     39.95434033705493
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "McDonald's",
#                 "address_line2": "3935 Walnut Street, Philadelphia, PA 19104, United States of America",
#                 "categories": [
#                     "building",
#                     "building.catering",
#                     "catering",
#                     "catering.fast_food",
#                     "catering.fast_food.burger"
#                 ],
#                 "city": "Philadelphia",
#                 "country": "United States",
#                 "country_code": "us",
#                 "county": "Philadelphia County",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:city": "Philadelphia",
#                         "addr:housenumber": 3935,
#                         "addr:postcode": 19104,
#                         "addr:street": "Walnut Street",
#                         "amenity": "fast_food",
#                         "brand": "McDonald's",
#                         "brand:wikidata": "Q38076",
#                         "brand:wikipedia": "en:McDonald's",
#                         "building": "yes",
#                         "cuisine": "burger",
#                         "drive_through": "no",
#                         "name": "McDonald's",
#                         "opening_hours": "24/7",
#                         "operator": "McDonald's",
#                         "osm_id": 51367806,
#                         "osm_type": "w",
#                         "phone": "+1 215 222 6266",
#                         "ref": 1602,
#                         "smoking": "no",
#                         "takeaway": "yes",
#                         "website": "http://www.mcpennsylvania.com/1602"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.catering",
#                     "details.contact",
#                     "details.facilities"
#                 ],
#                 "formatted": "McDonald's, 3935 Walnut Street, Philadelphia, PA 19104, United States of America",
#                 "housenumber": "3935",
#                 "lat": 39.954340349999995,
#                 "lon": -75.20233757664474,
#                 "name": "McDonald's",
#                 "place_id": "514a015019f3cc52c059c873fcd227fa4340f00102f9017ecf0f030000000092030a4d63446f6e616c642773",
#                 "postcode": "19104",
#                 "state": "Pennsylvania",
#                 "state_code": "PA",
#                 "street": "Walnut Street"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -75.14102741578348,
#                     39.94232006534343
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Moshulu",
#                 "address_line2": "South Christopher Columbus Boulevard, Philadelphia, PA 19106, United States of America",
#                 "categories": [
#                     "building",
#                     "building.catering",
#                     "building.historic",
#                     "catering",
#                     "catering.restaurant",
#                     "catering.restaurant.american",
#                     "tourism",
#                     "tourism.sights",
#                     "tourism.sights.memorial",
#                     "tourism.sights.memorial.ship",
#                     "wheelchair",
#                     "wheelchair.yes"
#                 ],
#                 "city": "Philadelphia",
#                 "country": "United States",
#                 "country_code": "us",
#                 "county": "Philadelphia County",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:city": "Philadelphia",
#                         "addr:postcode": 19106,
#                         "addr:state": "PA",
#                         "addr:street": "South Christopher Columbus Boulevard",
#                         "amenity": "restaurant",
#                         "building": "yes",
#                         "cuisine": "american",
#                         "historic": "ship",
#                         "name": "Moshulu",
#                         "osm_id": 170349587,
#                         "osm_type": "w",
#                         "outdoor_seating": "yes",
#                         "payment:cards": "yes",
#                         "payment:cash": "yes",
#                         "phone": "+1 215-923-2500",
#                         "ship:type": "cargo_ship",
#                         "start_date": 1904,
#                         "website": "https://www.moshulu.com/",
#                         "wheelchair": "yes",
#                         "wikidata": "Q20688",
#                         "wikipedia": "en:Moshulu"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.building",
#                     "details.catering",
#                     "details.contact",
#                     "details.facilities",
#                     "details.historic",
#                     "details.payment",
#                     "details.wiki_and_media"
#                 ],
#                 "district": "Society Hill",
#                 "formatted": "Moshulu, South Christopher Columbus Boulevard, Philadelphia, PA 19106, United States of America",
#                 "lat": 39.942288649999995,
#                 "lon": -75.14102822596303,
#                 "name": "Moshulu",
#                 "place_id": "5149a8da9706c952c059df81a3f19df84340f00102f9011354270a000000009203074d6f7368756c75",
#                 "postcode": "19106",
#                 "state": "Pennsylvania",
#                 "state_code": "PA",
#                 "street": "South Christopher Columbus Boulevard",
#                 "suburb": "Center City"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -75.20911325,
#                     39.94980285026048
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Green Line Cafe",
#                 "address_line2": "4239 Baltimore Avenue, Philadelphia, PA 19104, United States of America",
#                 "categories": [
#                     "building",
#                     "building.catering",
#                     "catering",
#                     "catering.cafe",
#                     "catering.cafe.coffee",
#                     "catering.cafe.coffee_shop",
#                     "vegan"
#                 ],
#                 "city": "Philadelphia",
#                 "country": "United States",
#                 "country_code": "us",
#                 "county": "Philadelphia County",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:housenumber": 4239,
#                         "addr:street": "Baltimore Avenue",
#                         "amenity": "cafe",
#                         "building": "yes",
#                         "cuisine": "coffee_shop",
#                         "diet:vegan": "yes",
#                         "name": "Green Line Cafe",
#                         "opening_hours": "Mo-Th 06:30-22:30; Fr 06:30-21:00; Sa 07:00-21:00; Su 08:00-21:00",
#                         "osm_id": 197012479,
#                         "osm_type": "w",
#                         "phone": "+1 215-222-3431",
#                         "website": "https://greenlinecafe.com/",
#                         "wifi": "no"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.catering",
#                     "details.contact"
#                 ],
#                 "district": "Southwest Schuylkill",
#                 "formatted": "Green Line Cafe, 4239 Baltimore Avenue, Philadelphia, PA 19104, United States of America",
#                 "housenumber": "4239",
#                 "lat": 39.94980285,
#                 "lon": -75.20911325,
#                 "name": "Green Line Cafe",
#                 "place_id": "51427a8a1c62cd52c05918c2c92393f94340f00102f901ff2bbe0b0000000092030f477265656e204c696e652043616665",
#                 "postcode": "19104",
#                 "state": "Pennsylvania",
#                 "state_code": "PA",
#                 "street": "Baltimore Avenue"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -75.21167010501092,
#                     39.9539690587266
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Green Line Cafe",
#                 "address_line2": "4426 Locust Street, Philadelphia, PA 19139, United States of America",
#                 "categories": [
#                     "building",
#                     "building.catering",
#                     "catering",
#                     "catering.cafe",
#                     "catering.cafe.coffee",
#                     "catering.cafe.coffee_shop",
#                     "vegan"
#                 ],
#                 "city": "Philadelphia",
#                 "country": "United States",
#                 "country_code": "us",
#                 "county": "Philadelphia County",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:city": "Philadelphia",
#                         "addr:housenumber": 4426,
#                         "addr:street": "Locust Street",
#                         "amenity": "cafe",
#                         "building": "yes",
#                         "cuisine": "coffee_shop",
#                         "diet:vegan": "yes",
#                         "name": "Green Line Cafe",
#                         "opening_hours": "Mo-Sa 07:00-21:00; Su 08:00-20:00",
#                         "osm_id": 197012480,
#                         "osm_type": "w",
#                         "phone": "+1 215-222-0799",
#                         "website": "https://greenlinecafe.com/"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.catering",
#                     "details.contact"
#                 ],
#                 "district": "Garden Court",
#                 "formatted": "Green Line Cafe, 4426 Locust Street, Philadelphia, PA 19139, United States of America",
#                 "housenumber": "4426",
#                 "lat": 39.953968450000005,
#                 "lon": -75.21166955530873,
#                 "name": "Green Line Cafe",
#                 "place_id": "5105a4c4008ccd52c05936507aa81bfa4340f00102f901002cbe0b0000000092030f477265656e204c696e652043616665",
#                 "postcode": "19139",
#                 "state": "Pennsylvania",
#                 "state_code": "PA",
#                 "street": "Locust Street"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -75.20938329204654,
#                     39.949737338428804
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Clarkville",
#                 "address_line2": "4301 Baltimore Avenue, Philadelphia, PA 19104, United States of America",
#                 "categories": [
#                     "building",
#                     "building.catering",
#                     "catering",
#                     "catering.restaurant",
#                     "catering.restaurant.pizza",
#                     "vegan",
#                     "vegetarian"
#                 ],
#                 "city": "Philadelphia",
#                 "country": "United States",
#                 "country_code": "us",
#                 "county": "Philadelphia County",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:city": "Philadelphia",
#                         "addr:housenumber": 4301,
#                         "addr:postcode": 19104,
#                         "addr:state": "PA",
#                         "addr:street": "Baltimore Ave",
#                         "amenity": "restaurant",
#                         "building": "yes",
#                         "cuisine": "pizza",
#                         "diet:vegan": "yes",
#                         "diet:vegetarian": "yes",
#                         "name": "Clarkville",
#                         "opening_hours": "12:00-20:00",
#                         "osm_id": 200002962,
#                         "osm_type": "w",
#                         "phone": "+1 215-387-4992",
#                         "website": "https://clarkvillephilly.com/"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.catering",
#                     "details.contact"
#                 ],
#                 "district": "Southwest Schuylkill",
#                 "formatted": "Clarkville, 4301 Baltimore Avenue, Philadelphia, PA 19104, United States of America",
#                 "housenumber": "4301",
#                 "lat": 39.9497368,
#                 "lon": -75.20938321649061,
#                 "name": "Clarkville",
#                 "place_id": "51ccea2d8966cd52c059c02b3cfe90f94340f00102f90192cdeb0b0000000092030a436c61726b76696c6c65",
#                 "postcode": "19104",
#                 "state": "Pennsylvania",
#                 "state_code": "PA",
#                 "street": "Baltimore Avenue"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -75.2021435326295,
#                     39.95432114487178
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Hummus Grill",
#                 "address_line2": "3931 Walnut Street, Philadelphia, PA 19104, United States of America",
#                 "categories": [
#                     "building",
#                     "building.catering",
#                     "catering",
#                     "catering.restaurant",
#                     "catering.restaurant.mediterranean"
#                 ],
#                 "city": "Philadelphia",
#                 "country": "United States",
#                 "country_code": "us",
#                 "county": "Philadelphia County",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:city": "Philadelphia",
#                         "addr:housenumber": 3931,
#                         "addr:postcode": 19104,
#                         "addr:state": "PA",
#                         "addr:street": "Walnut Street",
#                         "amenity": "restaurant",
#                         "building": "yes",
#                         "cuisine": "mediterranean",
#                         "name": "Hummus Grill",
#                         "opening_hours": "Mo-Fr 11:00-20:45; Sa 11:00-19:45; Su 12:00-20:45",
#                         "osm_id": 200676626,
#                         "osm_type": "w",
#                         "phone": "+1-215-222-5300",
#                         "website": "https://www.hummusrestaurant.com/"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.catering",
#                     "details.contact"
#                 ],
#                 "formatted": "Hummus Grill, 3931 Walnut Street, Philadelphia, PA 19104, United States of America",
#                 "housenumber": "3931",
#                 "lat": 39.9543369,
#                 "lon": -75.2021419148756,
#                 "name": "Hummus Grill",
#                 "place_id": "51776f6debefcc52c059838dfd3127fa4340f00102f9011215f60b0000000092030c48756d6d7573204772696c6c",
#                 "postcode": "19104",
#                 "state": "Pennsylvania",
#                 "state_code": "PA",
#                 "street": "Walnut Street"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -75.09967066897543,
#                     40.02902288772042
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Chick-fil-A",
#                 "address_line2": "4670 Roosevelt Boulevard, Philadelphia, PA 19124, United States of America",
#                 "categories": [
#                     "building",
#                     "building.catering",
#                     "catering",
#                     "catering.fast_food"
#                 ],
#                 "city": "Philadelphia",
#                 "country": "United States",
#                 "country_code": "us",
#                 "county": "Philadelphia County",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:city": "Philadelphia",
#                         "addr:housenumber": 4670,
#                         "addr:postcode": 19124,
#                         "addr:state": "PA",
#                         "addr:street": "Roosevelt Boulevard",
#                         "amenity": "fast_food",
#                         "brand": "Chick-fil-A",
#                         "brand:wikidata": "Q491516",
#                         "brand:wikipedia": "en:Chick-fil-A",
#                         "building": "yes",
#                         "cuisine": "chicken",
#                         "drive_through": "yes",
#                         "name": "Chick-fil-A",
#                         "opening_hours": "Mo-Sa 06:30-22:00",
#                         "osm_id": 210856703,
#                         "osm_type": "w",
#                         "phone": "+12155350352",
#                         "takeaway": "yes",
#                         "website": "https://www.chick-fil-a.com/locations/pa/northeast-tower"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.catering",
#                     "details.contact",
#                     "details.facilities"
#                 ],
#                 "district": "Cedar Grove",
#                 "formatted": "Chick-fil-A, 4670 Roosevelt Boulevard, Philadelphia, PA 19124, United States of America",
#                 "housenumber": "4670",
#                 "lat": 40.02901835,
#                 "lon": -75.09967946421719,
#                 "name": "Chick-fil-A",
#                 "place_id": "51ade7150161c652c0591fcca005b7034440f00102f901ff6a910c0000000092030b436869636b2d66696c2d41",
#                 "postcode": "19124",
#                 "state": "Pennsylvania",
#                 "state_code": "PA",
#                 "street": "Roosevelt Boulevard"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -75.16650034999998,
#                     39.95543595026125
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Capriccio",
#                 "address_line2": "110 North 16th Street, Philadelphia, PA 19102, United States of America",
#                 "categories": [
#                     "building",
#                     "building.catering",
#                     "catering",
#                     "catering.cafe",
#                     "catering.cafe.coffee",
#                     "catering.cafe.coffee_shop"
#                 ],
#                 "city": "Philadelphia",
#                 "country": "United States",
#                 "country_code": "us",
#                 "county": "Philadelphia County",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:city": "Philadelphia",
#                         "addr:housenumber": 110,
#                         "addr:postcode": 19102,
#                         "addr:street": "North 16th Street",
#                         "amenity": "cafe",
#                         "building": "yes",
#                         "building:levels": 1,
#                         "cuisine": "coffee_shop",
#                         "name": "Capriccio",
#                         "opening_hours": "Mo-Fr 06:30-19:00; Sa-Su 08:00-20:00",
#                         "osm_id": 239873161,
#                         "osm_type": "w",
#                         "phone": "+1 215 735 9797",
#                         "website": "https://www.capricciocafe.com/"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.building",
#                     "details.catering",
#                     "details.contact"
#                 ],
#                 "formatted": "Capriccio, 110 North 16th Street, Philadelphia, PA 19102, United States of America",
#                 "housenumber": "110",
#                 "lat": 39.95543595,
#                 "lon": -75.16650035,
#                 "name": "Capriccio",
#                 "place_id": "51708115f1a7ca52c059bae5a7b94bfa4340f00102f901892c4c0e0000000092030943617072696363696f",
#                 "postcode": "19102",
#                 "state": "Pennsylvania",
#                 "state_code": "PA",
#                 "street": "North 16th Street",
#                 "suburb": "Center City"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -75.14457503877111,
#                     39.94713237322507
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "City Tavern",
#                 "address_line2": "South 2nd Street, Philadelphia, PA 19106, United States of America",
#                 "categories": [
#                     "building",
#                     "building.catering",
#                     "building.historic",
#                     "building.tourism",
#                     "catering",
#                     "catering.restaurant",
#                     "tourism",
#                     "tourism.attraction",
#                     "tourism.sights"
#                 ],
#                 "city": "Philadelphia",
#                 "country": "United States",
#                 "country_code": "us",
#                 "county": "Philadelphia County",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "restaurant",
#                         "building": "yes",
#                         "historic": "building",
#                         "name": "City Tavern",
#                         "osm_id": 261314257,
#                         "osm_type": "w",
#                         "phone": "+1 215-413-1443",
#                         "tourism": "attraction",
#                         "website": "https://www.citytavern.com/",
#                         "wikidata": "Q2974580",
#                         "wikipedia": "en:City Tavern"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.contact",
#                     "details.wiki_and_media"
#                 ],
#                 "district": "Society Hill",
#                 "formatted": "City Tavern, South 2nd Street, Philadelphia, PA 19106, United States of America",
#                 "lat": 39.9471264,
#                 "lon": -75.14455590138334,
#                 "name": "City Tavern",
#                 "place_id": "51c0d5a9b740c952c05905fe33a23bf94340f00102f901d156930f0000000092030b436974792054617665726e",
#                 "postcode": "19106",
#                 "state": "Pennsylvania",
#                 "state_code": "PA",
#                 "street": "South 2nd Street",
#                 "suburb": "Center City"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -75.17148637534407,
#                     39.92727858579866
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "South Philadelphia Tap Room",
#                 "address_line2": "1509 Mifflin Street, Philadelphia, PA 19145, United States of America",
#                 "categories": [
#                     "building",
#                     "building.catering",
#                     "building.commercial",
#                     "catering",
#                     "catering.bar"
#                 ],
#                 "city": "Philadelphia",
#                 "country": "United States",
#                 "country_code": "us",
#                 "county": "Philadelphia County",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:city": "Philadelphia",
#                         "addr:housenumber": 1509,
#                         "addr:postcode": 19145,
#                         "addr:street": "Mifflin Street",
#                         "amenity": "bar",
#                         "atm": "yes",
#                         "building": "yes",
#                         "building:levels": 2,
#                         "cuisine": "gastropub",
#                         "food": "yes",
#                         "name": "South Philadelphia Tap Room",
#                         "opening_hours": "11:00-02:00",
#                         "osm_id": 269853604,
#                         "osm_type": "w",
#                         "outdoor_seating": "yes",
#                         "phone": "+1 215 271 7787",
#                         "website": "http://www.southphiladelphiataproom.com/index2.html"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.building",
#                     "details.catering",
#                     "details.contact",
#                     "details.facilities"
#                 ],
#                 "district": "Wharton",
#                 "formatted": "South Philadelphia Tap Room, 1509 Mifflin Street, Philadelphia, PA 19145, United States of America",
#                 "housenumber": "1509",
#                 "lat": 39.927239900000004,
#                 "lon": -75.17149747292171,
#                 "name": "South Philadelphia Tap Room",
#                 "place_id": "51fe73fda1f9ca52c059a8249010b1f64340f00102f901a4a315100000000092031b536f757468205068696c6164656c706869612054617020526f6f6d",
#                 "postcode": "19145",
#                 "state": "Pennsylvania",
#                 "state_code": "PA",
#                 "street": "Mifflin Street",
#                 "suburb": "South Philadelphia"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -75.12701519946164,
#                     39.97647497407387
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "ReAnimator Coffee",
#                 "address_line2": "1523 East Susquehanna Avenue, Philadelphia, PA 19125, United States of America",
#                 "categories": [
#                     "building",
#                     "building.catering",
#                     "catering",
#                     "catering.cafe",
#                     "internet_access"
#                 ],
#                 "city": "Philadelphia",
#                 "country": "United States",
#                 "country_code": "us",
#                 "county": "Philadelphia County",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:city": "Philadelphia",
#                         "addr:housenumber": 1523,
#                         "addr:postcode": 19125,
#                         "addr:street": "East Susquehanna Avenue",
#                         "amenity": "cafe",
#                         "building": "yes",
#                         "internet_access": "yes",
#                         "name": "ReAnimator Coffee",
#                         "opening_hours": "Mo-Fr 06:30-19:00; Sa-Su 08:00-19:00",
#                         "osm_id": 287693940,
#                         "osm_type": "w",
#                         "phone": "(215) 425-5805",
#                         "website": "https://www.reanimatorcoffee.com/"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.contact",
#                     "details.facilities"
#                 ],
#                 "district": "Fishtown",
#                 "formatted": "ReAnimator Coffee, 1523 East Susquehanna Avenue, Philadelphia, PA 19125, United States of America",
#                 "housenumber": "1523",
#                 "lat": 39.97649555,
#                 "lon": -75.1270346427051,
#                 "name": "ReAnimator Coffee",
#                 "place_id": "5117f25b0421c852c0593e81c721fdfc4340f00102f90174dc2511000000009203115265416e696d61746f7220436f66666565",
#                 "postcode": "19125",
#                 "state": "Pennsylvania",
#                 "state_code": "PA",
#                 "street": "East Susquehanna Avenue"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -75.15837334999999,
#                     39.95055630026057
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Paulies Pizza",
#                 "address_line2": "31 South 11th Street, Philadelphia, PA 19107, United States of America",
#                 "categories": [
#                     "building",
#                     "building.catering",
#                     "catering",
#                     "catering.restaurant",
#                     "catering.restaurant.pizza"
#                 ],
#                 "city": "Philadelphia",
#                 "country": "United States",
#                 "country_code": "us",
#                 "county": "Philadelphia County",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:city": "Philadelphia",
#                         "addr:housenumber": 31,
#                         "addr:postcode": 19107,
#                         "addr:state": "PA",
#                         "addr:street": "South 11th Street",
#                         "amenity": "restaurant",
#                         "building": "yes",
#                         "building:levels": 4,
#                         "capacity": 30,
#                         "cuisine": "pizza",
#                         "delivery": "yes",
#                         "level": 4,
#                         "name": "Paulies Pizza",
#                         "opening_hours": "Mo-Th 10:00-24:00; Fr-Sa 10:00-04:00; Su 11:00-23:00",
#                         "osm_id": 333012738,
#                         "osm_type": "w",
#                         "outdoor_seating": "no",
#                         "phone": "+1-215-592-4715",
#                         "smoking": "no",
#                         "takeaway": "yes",
#                         "website": "https://www.pauliespizzaphiladelphia.com/"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.building",
#                     "details.catering",
#                     "details.contact",
#                     "details.facilities"
#                 ],
#                 "district": "Gayborhood",
#                 "formatted": "Paulies Pizza, 31 South 11th Street, Philadelphia, PA 19107, United States of America",
#                 "housenumber": "31",
#                 "lat": 39.9505563,
#                 "lon": -75.15837335,
#                 "name": "Paulies Pizza",
#                 "place_id": "51b5b3f9c922ca52c0591e502fd4abf94340f00102f901025fd9130000000092030d5061756c6965732050697a7a61",
#                 "postcode": "19107",
#                 "state": "Pennsylvania",
#                 "state_code": "PA",
#                 "street": "South 11th Street",
#                 "suburb": "Center City"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -75.17074175311855,
#                     39.95101507619146
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "The Dandelion",
#                 "address_line2": "124 South 18th Street, Philadelphia, PA 19103, United States of America",
#                 "categories": [
#                     "building",
#                     "building.catering",
#                     "catering",
#                     "catering.pub"
#                 ],
#                 "city": "Philadelphia",
#                 "country": "United States",
#                 "country_code": "us",
#                 "county": "Philadelphia County",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:city": "Philadelphia",
#                         "addr:housenumber": 124,
#                         "addr:postcode": 19103,
#                         "addr:street": "South 18th Street",
#                         "air_conditioning": "yes",
#                         "amenity": "pub",
#                         "building": "yes",
#                         "building:levels": 3,
#                         "email": "thedandelion.info@starr-restaurants.com",
#                         "name": "The Dandelion",
#                         "opening_hours": "Mo-Th 11:30-23:00; Fr 11:30-00:00; Sa 10:00-00:00; Su 10:00-22:00",
#                         "osm_id": 336505649,
#                         "osm_type": "w",
#                         "phone": "+1 215 558 2500",
#                         "roof:levels": 1,
#                         "smoking": "no",
#                         "toilets": "yes",
#                         "website": "https://thedandelionpub.com/"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.building",
#                     "details.contact",
#                     "details.facilities"
#                 ],
#                 "district": "Rittenhouse Square",
#                 "formatted": "The Dandelion, 124 South 18th Street, Philadelphia, PA 19103, United States of America",
#                 "housenumber": "124",
#                 "lat": 39.95101485,
#                 "lon": -75.17074136802594,
#                 "name": "The Dandelion",
#                 "place_id": "512d6dd16eedca52c059651faddcbaf94340f00102f90131ab0e140000000092030d5468652044616e64656c696f6e",
#                 "postcode": "19103",
#                 "state": "Pennsylvania",
#                 "state_code": "PA",
#                 "street": "South 18th Street",
#                 "suburb": "Center City"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -75.19252357223019,
#                     39.95349006930155
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Avril 50",
#                 "address_line2": "3406 Sansom Street, Philadelphia, PA 19104, United States of America",
#                 "categories": [
#                     "building",
#                     "building.catering",
#                     "building.commercial",
#                     "catering",
#                     "catering.cafe",
#                     "catering.cafe.coffee",
#                     "catering.cafe.coffee_shop",
#                     "commercial"
#                 ],
#                 "city": "Philadelphia",
#                 "country": "United States",
#                 "country_code": "us",
#                 "county": "Philadelphia County",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:city": "Philadelphia",
#                         "addr:country": "US",
#                         "addr:housenumber": 3406,
#                         "addr:postcode": 19104,
#                         "addr:state": "PA",
#                         "addr:street": "Sansom Street",
#                         "amenity": "cafe",
#                         "building": "yes",
#                         "cuisine": "coffee_shop",
#                         "description": "International publications fine cards, gourmet coffee, tea, chocolate &#38;#38; tobacco",
#                         "drink:club-mate": "retail",
#                         "email": "info@avril50.com",
#                         "name": "Avril 50",
#                         "opening_hours": "Mo-Fr 07:30-18:00; Sa 10:00-17:00",
#                         "osm_id": 369570963,
#                         "osm_type": "w",
#                         "outdoor_seating": "yes",
#                         "phone": "+1-215-222-6108",
#                         "shop": "coffee;cards;chocolate;tobacco;tea;magazines",
#                         "website": "http://avril50.com/"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.catering",
#                     "details.contact",
#                     "details.facilities"
#                 ],
#                 "district": "University City",
#                 "formatted": "Avril 50, 3406 Sansom Street, Philadelphia, PA 19104, United States of America",
#                 "housenumber": "3406",
#                 "lat": 39.9534493,
#                 "lon": -75.19253512569071,
#                 "name": "Avril 50",
#                 "place_id": "51049c634e52cc52c059005b6cf60bfa4340f00102f9019334071600000000920308417672696c203530",
#                 "postcode": "19104",
#                 "state": "Pennsylvania",
#                 "state_code": "PA",
#                 "street": "Sansom Street"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -75.19296599999998,
#                     39.953562150261
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "White Dog Cafe",
#                 "address_line2": "3420 Sansom Street, Philadelphia, PA 19104, United States of America",
#                 "categories": [
#                     "building",
#                     "building.catering",
#                     "building.commercial",
#                     "catering",
#                     "catering.restaurant"
#                 ],
#                 "city": "Philadelphia",
#                 "country": "United States",
#                 "country_code": "us",
#                 "county": "Philadelphia County",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:city": "Philadelphia",
#                         "addr:country": "US",
#                         "addr:housenumber": 3420,
#                         "addr:postcode": 19104,
#                         "addr:state": "PA",
#                         "addr:street": "Sansom Street",
#                         "amenity": "restaurant",
#                         "building": "commercial",
#                         "email": "universitycity@whitedog.com",
#                         "name": "White Dog Cafe",
#                         "opening_hours": "Mo-Fr 11:00-14:30; Sa-Su 09:30-14:30; Mo-Su 14:30-17:00; Mo-Th 17:00-21:30; Fr-Sa 17:00-22:00; Su 17:00-21:00",
#                         "osm_id": 369570967,
#                         "osm_type": "w",
#                         "phone": "+1-215-386-9224",
#                         "website": "https://www.whitedog.com/"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.contact"
#                 ],
#                 "district": "University City",
#                 "formatted": "White Dog Cafe, 3420 Sansom Street, Philadelphia, PA 19104, United States of America",
#                 "housenumber": "3420",
#                 "lat": 39.953562149999996,
#                 "lon": -75.192966,
#                 "name": "White Dog Cafe",
#                 "place_id": "515acf108e59cc52c059870915530efa4340f00102f901973407160000000092030e576869746520446f672043616665",
#                 "postcode": "19104",
#                 "state": "Pennsylvania",
#                 "state_code": "PA",
#                 "street": "Sansom Street"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -75.07339356159393,
#                     39.99749875123103
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Old English Pizzeria",
#                 "address_line2": "2765 Orthodox Street, Philadelphia, PA 19137, United States of America",
#                 "categories": [
#                     "building",
#                     "building.catering",
#                     "catering",
#                     "catering.restaurant",
#                     "catering.restaurant.american",
#                     "wheelchair",
#                     "wheelchair.yes"
#                 ],
#                 "city": "Philadelphia",
#                 "country": "United States",
#                 "country_code": "us",
#                 "county": "Philadelphia County",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:city": "Philadelphia",
#                         "addr:country": "US",
#                         "addr:housenumber": 2765,
#                         "addr:postcode": 19137,
#                         "addr:state": "PA",
#                         "addr:street": "Orthodox Street",
#                         "amenity": "restaurant",
#                         "building": "yes",
#                         "cuisine": "american",
#                         "delivery": "yes",
#                         "name": "Old English Pizzeria",
#                         "opening_hours": "Mo-Sa 11:00-01:00, Su 11:00-23:00",
#                         "osm_id": 374115857,
#                         "osm_type": "w",
#                         "phone": "(215) 288-9900",
#                         "smoking": "no",
#                         "takeaway": "yes",
#                         "website": "https://philadelphia.menupages.com/restaurants/old-english-pizza/menu",
#                         "wheelchair": "yes"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.catering",
#                     "details.contact",
#                     "details.facilities"
#                 ],
#                 "district": "Bridesburg",
#                 "formatted": "Old English Pizzeria, 2765 Orthodox Street, Philadelphia, PA 19137, United States of America",
#                 "housenumber": "2765",
#                 "lat": 39.99750085,
#                 "lon": -75.07339132297155,
#                 "name": "Old English Pizzeria",
#                 "place_id": "511bb2e87ab2c452c059472b010aaeff4340f00102f901118e4c16000000009203144f6c6420456e676c6973682050697a7a65726961",
#                 "postcode": "19137",
#                 "state": "Pennsylvania",
#                 "state_code": "PA",
#                 "street": "Orthodox Street"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -75.23287285080215,
#                     40.08343105491131
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "The Cedars House",
#                 "address_line2": "Forbidden Drive, Philadelphia, PA 19128, United States of America",
#                 "categories": [
#                     "building",
#                     "building.catering",
#                     "catering",
#                     "catering.cafe"
#                 ],
#                 "city": "Philadelphia",
#                 "country": "United States",
#                 "country_code": "us",
#                 "county": "Philadelphia County",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "cafe",
#                         "building": "yes",
#                         "name": "The Cedars House",
#                         "opening_hours": "08:00-15:00",
#                         "osm_id": 420873512,
#                         "osm_type": "w",
#                         "outdoor_seating": "yes",
#                         "website": "https://thecedarshouse.com/",
#                         "wikidata": "Q114615434"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.catering",
#                     "details.facilities",
#                     "details.wiki_and_media"
#                 ],
#                 "formatted": "The Cedars House, Forbidden Drive, Philadelphia, PA 19128, United States of America",
#                 "lat": 40.083422850000005,
#                 "lon": -75.23286875,
#                 "name": "The Cedars House",
#                 "place_id": "5194948763e7ce52c0594d286adead0a4440f00102f90128051619000000009203105468652043656461727320486f757365",
#                 "postcode": "19128",
#                 "state": "Pennsylvania",
#                 "state_code": "PA",
#                 "street": "Forbidden Drive"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -75.17173740585312,
#                     39.924854022646436
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Melrose Diner",
#                 "address_line2": "1501 Snyder Avenue, Philadelphia, PA 19145, United States of America",
#                 "categories": [
#                     "building",
#                     "building.catering",
#                     "catering",
#                     "catering.restaurant"
#                 ],
#                 "city": "Philadelphia",
#                 "country": "United States",
#                 "country_code": "us",
#                 "county": "Philadelphia County",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:city": "Philadelphia",
#                         "addr:housenumber": 1501,
#                         "addr:postcode": 19145,
#                         "addr:state": "PA",
#                         "addr:street": "Snyder Avenue",
#                         "amenity": "restaurant",
#                         "building": "yes",
#                         "name": "Melrose Diner",
#                         "opening_hours": "24/7",
#                         "osm_id": 438545000,
#                         "osm_type": "w",
#                         "phone": "+1 215 467 6644",
#                         "takeaway": "yes",
#                         "website": "https://www.themelrosedinerandbakery.com/"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.catering",
#                     "details.contact",
#                     "details.facilities"
#                 ],
#                 "formatted": "Melrose Diner, 1501 Snyder Avenue, Philadelphia, PA 19145, United States of America",
#                 "housenumber": "1501",
#                 "lat": 39.92486685,
#                 "lon": -75.17176139055883,
#                 "name": "Melrose Diner",
#                 "place_id": "51e668e3befdca52c059956bda9d61f64340f00102f90168aa231a0000000092030d4d656c726f73652044696e6572",
#                 "postcode": "19145",
#                 "state": "Pennsylvania",
#                 "state_code": "PA",
#                 "street": "Snyder Avenue",
#                 "suburb": "South Philadelphia"
#             },
#             "type": "Feature"
#         }
#     ],
#     "type": "FeatureCollection"
# }

# %%
lat = geo_data["features"][0]["properties"]
lon = geo_data["features"][0]["properties"]

print('''
    City: {0}
    Latitude: {1}
    Longitude: {2}
    '''.format(target_city, lat, lon))
# Out:
#     City: Philadelphia, Pennsylvania
#     Latitude: {'name': 'Valley Green Inn', 'country': 'United States', 'country_code': 'us', 'state': 'Pennsylvania', 'county': 'Philadelphia County', 'city': 'Philadelphia', 'postcode': '19128', 'street': 'Valley Green Road', 'lon': -75.21821459327312, 'lat': 40.05408665, 'state_code': 'PA', 'formatted': 'Valley Green Inn, Valley Green Road, Philadelphia, PA 19128, United States of America', 'address_line1': 'Valley Green Inn', 'address_line2': 'Valley Green Road, Philadelphia, PA 19128, United States of America', 'categories': ['building', 'building.catering', 'building.historic', 'catering', 'catering.restaurant', 'catering.restaurant.american', 'tourism', 'tourism.sights', 'vegan', 'vegetarian'], 'details': ['details', 'details.catering', 'details.contact', 'details.wiki_and_media'], 'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database Licence', 'url': 'https://www.openstreetmap.org/copyright', 'raw': {'name': 'Valley Green Inn', 'phone': '+1-215-247-1730', 'osm_id': 52495244, 'amenity': 'restaurant', 'cuisine': 'american', 'website': 'http://www.valleygreeninn.com', 'building': 'yes', 'historic': 'building', 'osm_type': 'w', 'wikidata': 'Q78827991', 'addr:city': 'Philadelphia', 'addr:state': 'PA', 'diet:vegan': 'yes', 'addr:street': 'Valley Green Road', 'addr:postcode': 19128, 'opening_hours': 'Mo-Fr 12:00-16:00; Sa 11:00-16:00; Mo-Th 17:00-21:00; Fr-Sa 17:00-22:00; Su 10:00-15:00', 'addr:housename': 'Valley Green Inn', 'diet:vegetarian': 'yes', 'diet:pescetarian': 'yes'}}, 'place_id': '51339f9820f7cd52c0590510ea90ec064440f00102f9018c0321030000000092031056616c6c657920477265656e20496e6e'}
#     Longitude: {'name': 'Valley Green Inn', 'country': 'United States', 'country_code': 'us', 'state': 'Pennsylvania', 'county': 'Philadelphia County', 'city': 'Philadelphia', 'postcode': '19128', 'street': 'Valley Green Road', 'lon': -75.21821459327312, 'lat': 40.05408665, 'state_code': 'PA', 'formatted': 'Valley Green Inn, Valley Green Road, Philadelphia, PA 19128, United States of America', 'address_line1': 'Valley Green Inn', 'address_line2': 'Valley Green Road, Philadelphia, PA 19128, United States of America', 'categories': ['building', 'building.catering', 'building.historic', 'catering', 'catering.restaurant', 'catering.restaurant.american', 'tourism', 'tourism.sights', 'vegan', 'vegetarian'], 'details': ['details', 'details.catering', 'details.contact', 'details.wiki_and_media'], 'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database Licence', 'url': 'https://www.openstreetmap.org/copyright', 'raw': {'name': 'Valley Green Inn', 'phone': '+1-215-247-1730', 'osm_id': 52495244, 'amenity': 'restaurant', 'cuisine': 'american', 'website': 'http://www.valleygreeninn.com', 'building': 'yes', 'historic': 'building', 'osm_type': 'w', 'wikidata': 'Q78827991', 'addr:city': 'Philadelphia', 'addr:state': 'PA', 'diet:vegan': 'yes', 'addr:street': 'Valley Green Road', 'addr:postcode': 19128, 'opening_hours': 'Mo-Fr 12:00-16:00; Sa 11:00-16:00; Mo-Th 17:00-21:00; Fr-Sa 17:00-22:00; Su 10:00-15:00', 'addr:housename': 'Valley Green Inn', 'diet:vegetarian': 'yes', 'diet:pescetarian': 'yes'}}, 'place_id': '51339f9820f7cd52c0590510ea90ec064440f00102f9018c0321030000000092031056616c6c657920477265656e20496e6e'}

# %%
params = {
    "text": target_city,
    "geoapify_key": geoapify_key
}

# %%
response = requests.get(target_url, params=params).json()

print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "features": [
#         {
#             "geometry": {
#                 "coordinates": [
#                     -75.21820845512848,
#                     40.054094423569076
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Valley Green Inn",
#                 "address_line2": "Valley Green Road, Philadelphia, PA 19128, United States of America",
#                 "categories": [
#                     "building",
#                     "building.catering",
#                     "building.historic",
#                     "catering",
#                     "catering.restaurant",
#                     "catering.restaurant.american",
#                     "tourism",
#                     "tourism.sights",
#                     "vegan",
#                     "vegetarian"
#                 ],
#                 "city": "Philadelphia",
#                 "country": "United States",
#                 "country_code": "us",
#                 "county": "Philadelphia County",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:city": "Philadelphia",
#                         "addr:housename": "Valley Green Inn",
#                         "addr:postcode": 19128,
#                         "addr:state": "PA",
#                         "addr:street": "Valley Green Road",
#                         "amenity": "restaurant",
#                         "building": "yes",
#                         "cuisine": "american",
#                         "diet:pescetarian": "yes",
#                         "diet:vegan": "yes",
#                         "diet:vegetarian": "yes",
#                         "historic": "building",
#                         "name": "Valley Green Inn",
#                         "opening_hours": "Mo-Fr 12:00-16:00; Sa 11:00-16:00; Mo-Th 17:00-21:00; Fr-Sa 17:00-22:00; Su 10:00-15:00",
#                         "osm_id": 52495244,
#                         "osm_type": "w",
#                         "phone": "+1-215-247-1730",
#                         "website": "http://www.valleygreeninn.com",
#                         "wikidata": "Q78827991"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.catering",
#                     "details.contact",
#                     "details.wiki_and_media"
#                 ],
#                 "formatted": "Valley Green Inn, Valley Green Road, Philadelphia, PA 19128, United States of America",
#                 "lat": 40.05408665,
#                 "lon": -75.21821459327312,
#                 "name": "Valley Green Inn",
#                 "place_id": "51339f9820f7cd52c0590510ea90ec064440f00102f9018c0321030000000092031056616c6c657920477265656e20496e6e",
#                 "postcode": "19128",
#                 "state": "Pennsylvania",
#                 "state_code": "PA",
#                 "street": "Valley Green Road"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -75.1588206390958,
#                     39.93384898562501
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Geno's Steaks",
#                 "address_line2": "1219 South 9th Street, Philadelphia, PA 19147, United States of America",
#                 "categories": [
#                     "building",
#                     "building.catering",
#                     "catering",
#                     "catering.restaurant"
#                 ],
#                 "city": "Philadelphia",
#                 "country": "United States",
#                 "country_code": "us",
#                 "county": "Philadelphia County",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:city": "Philadelphia",
#                         "addr:housenumber": 1219,
#                         "addr:postcode": 19147,
#                         "addr:state": "PA",
#                         "addr:street": "S 9th St",
#                         "amenity": "restaurant",
#                         "building": "yes",
#                         "cuisine": "steak_house;cheesesteak",
#                         "description": "The place with the BEST Cheesesteak in Philly, Geno\u2019s was founded by one of Philly\u2019s own, Joey Vento in 1966. The man had two boxes of steaks, a few hot dogs, and $6 in his pocket when he turned on the grills at 9th and Passyunk. Neighboring joints predic",
#                         "image": "https://www.genosteaks.com/wp-content/uploads/2015/11/GenosLogo1.png",
#                         "name": "Geno's Steaks",
#                         "opening_hours": "24/7",
#                         "osm_id": 334890731,
#                         "osm_type": "w",
#                         "phone": "215-389-0659",
#                         "website": "https://www.genosteaks.com/"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.catering",
#                     "details.contact",
#                     "details.wiki_and_media"
#                 ],
#                 "district": "Little Saigon",
#                 "formatted": "Geno's Steaks, 1219 South 9th Street, Philadelphia, PA 19147, United States of America",
#                 "housenumber": "1219",
#                 "lat": 39.9338149,
#                 "lon": -75.15883871303394,
#                 "name": "Geno's Steaks",
#                 "place_id": "5129b60a1e2aca52c059c354125d88f74340f00102f901eb06f6130000000092030d47656e6f277320537465616b73",
#                 "postcode": "19147",
#                 "state": "Pennsylvania",
#                 "state_code": "PA",
#                 "street": "South 9th Street",
#                 "suburb": "South Philadelphia"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -75.20233757794372,
#                     39.95434033705493
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "McDonald's",
#                 "address_line2": "3935 Walnut Street, Philadelphia, PA 19104, United States of America",
#                 "categories": [
#                     "building",
#                     "building.catering",
#                     "catering",
#                     "catering.fast_food",
#                     "catering.fast_food.burger"
#                 ],
#                 "city": "Philadelphia",
#                 "country": "United States",
#                 "country_code": "us",
#                 "county": "Philadelphia County",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:city": "Philadelphia",
#                         "addr:housenumber": 3935,
#                         "addr:postcode": 19104,
#                         "addr:street": "Walnut Street",
#                         "amenity": "fast_food",
#                         "brand": "McDonald's",
#                         "brand:wikidata": "Q38076",
#                         "brand:wikipedia": "en:McDonald's",
#                         "building": "yes",
#                         "cuisine": "burger",
#                         "drive_through": "no",
#                         "name": "McDonald's",
#                         "opening_hours": "24/7",
#                         "operator": "McDonald's",
#                         "osm_id": 51367806,
#                         "osm_type": "w",
#                         "phone": "+1 215 222 6266",
#                         "ref": 1602,
#                         "smoking": "no",
#                         "takeaway": "yes",
#                         "website": "http://www.mcpennsylvania.com/1602"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.catering",
#                     "details.contact",
#                     "details.facilities"
#                 ],
#                 "formatted": "McDonald's, 3935 Walnut Street, Philadelphia, PA 19104, United States of America",
#                 "housenumber": "3935",
#                 "lat": 39.954340349999995,
#                 "lon": -75.20233757664474,
#                 "name": "McDonald's",
#                 "place_id": "514a015019f3cc52c059c873fcd227fa4340f00102f9017ecf0f030000000092030a4d63446f6e616c642773",
#                 "postcode": "19104",
#                 "state": "Pennsylvania",
#                 "state_code": "PA",
#                 "street": "Walnut Street"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -75.14102741578348,
#                     39.94232006534343
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Moshulu",
#                 "address_line2": "South Christopher Columbus Boulevard, Philadelphia, PA 19106, United States of America",
#                 "categories": [
#                     "building",
#                     "building.catering",
#                     "building.historic",
#                     "catering",
#                     "catering.restaurant",
#                     "catering.restaurant.american",
#                     "tourism",
#                     "tourism.sights",
#                     "tourism.sights.memorial",
#                     "tourism.sights.memorial.ship",
#                     "wheelchair",
#                     "wheelchair.yes"
#                 ],
#                 "city": "Philadelphia",
#                 "country": "United States",
#                 "country_code": "us",
#                 "county": "Philadelphia County",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:city": "Philadelphia",
#                         "addr:postcode": 19106,
#                         "addr:state": "PA",
#                         "addr:street": "South Christopher Columbus Boulevard",
#                         "amenity": "restaurant",
#                         "building": "yes",
#                         "cuisine": "american",
#                         "historic": "ship",
#                         "name": "Moshulu",
#                         "osm_id": 170349587,
#                         "osm_type": "w",
#                         "outdoor_seating": "yes",
#                         "payment:cards": "yes",
#                         "payment:cash": "yes",
#                         "phone": "+1 215-923-2500",
#                         "ship:type": "cargo_ship",
#                         "start_date": 1904,
#                         "website": "https://www.moshulu.com/",
#                         "wheelchair": "yes",
#                         "wikidata": "Q20688",
#                         "wikipedia": "en:Moshulu"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.building",
#                     "details.catering",
#                     "details.contact",
#                     "details.facilities",
#                     "details.historic",
#                     "details.payment",
#                     "details.wiki_and_media"
#                 ],
#                 "district": "Society Hill",
#                 "formatted": "Moshulu, South Christopher Columbus Boulevard, Philadelphia, PA 19106, United States of America",
#                 "lat": 39.942288649999995,
#                 "lon": -75.14102822596303,
#                 "name": "Moshulu",
#                 "place_id": "5149a8da9706c952c059df81a3f19df84340f00102f9011354270a000000009203074d6f7368756c75",
#                 "postcode": "19106",
#                 "state": "Pennsylvania",
#                 "state_code": "PA",
#                 "street": "South Christopher Columbus Boulevard",
#                 "suburb": "Center City"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -75.20911325,
#                     39.94980285026048
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Green Line Cafe",
#                 "address_line2": "4239 Baltimore Avenue, Philadelphia, PA 19104, United States of America",
#                 "categories": [
#                     "building",
#                     "building.catering",
#                     "catering",
#                     "catering.cafe",
#                     "catering.cafe.coffee",
#                     "catering.cafe.coffee_shop",
#                     "vegan"
#                 ],
#                 "city": "Philadelphia",
#                 "country": "United States",
#                 "country_code": "us",
#                 "county": "Philadelphia County",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:housenumber": 4239,
#                         "addr:street": "Baltimore Avenue",
#                         "amenity": "cafe",
#                         "building": "yes",
#                         "cuisine": "coffee_shop",
#                         "diet:vegan": "yes",
#                         "name": "Green Line Cafe",
#                         "opening_hours": "Mo-Th 06:30-22:30; Fr 06:30-21:00; Sa 07:00-21:00; Su 08:00-21:00",
#                         "osm_id": 197012479,
#                         "osm_type": "w",
#                         "phone": "+1 215-222-3431",
#                         "website": "https://greenlinecafe.com/",
#                         "wifi": "no"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.catering",
#                     "details.contact"
#                 ],
#                 "district": "Southwest Schuylkill",
#                 "formatted": "Green Line Cafe, 4239 Baltimore Avenue, Philadelphia, PA 19104, United States of America",
#                 "housenumber": "4239",
#                 "lat": 39.94980285,
#                 "lon": -75.20911325,
#                 "name": "Green Line Cafe",
#                 "place_id": "51427a8a1c62cd52c05918c2c92393f94340f00102f901ff2bbe0b0000000092030f477265656e204c696e652043616665",
#                 "postcode": "19104",
#                 "state": "Pennsylvania",
#                 "state_code": "PA",
#                 "street": "Baltimore Avenue"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -75.21167010501092,
#                     39.9539690587266
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Green Line Cafe",
#                 "address_line2": "4426 Locust Street, Philadelphia, PA 19139, United States of America",
#                 "categories": [
#                     "building",
#                     "building.catering",
#                     "catering",
#                     "catering.cafe",
#                     "catering.cafe.coffee",
#                     "catering.cafe.coffee_shop",
#                     "vegan"
#                 ],
#                 "city": "Philadelphia",
#                 "country": "United States",
#                 "country_code": "us",
#                 "county": "Philadelphia County",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:city": "Philadelphia",
#                         "addr:housenumber": 4426,
#                         "addr:street": "Locust Street",
#                         "amenity": "cafe",
#                         "building": "yes",
#                         "cuisine": "coffee_shop",
#                         "diet:vegan": "yes",
#                         "name": "Green Line Cafe",
#                         "opening_hours": "Mo-Sa 07:00-21:00; Su 08:00-20:00",
#                         "osm_id": 197012480,
#                         "osm_type": "w",
#                         "phone": "+1 215-222-0799",
#                         "website": "https://greenlinecafe.com/"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.catering",
#                     "details.contact"
#                 ],
#                 "district": "Garden Court",
#                 "formatted": "Green Line Cafe, 4426 Locust Street, Philadelphia, PA 19139, United States of America",
#                 "housenumber": "4426",
#                 "lat": 39.953968450000005,
#                 "lon": -75.21166955530873,
#                 "name": "Green Line Cafe",
#                 "place_id": "5105a4c4008ccd52c05936507aa81bfa4340f00102f901002cbe0b0000000092030f477265656e204c696e652043616665",
#                 "postcode": "19139",
#                 "state": "Pennsylvania",
#                 "state_code": "PA",
#                 "street": "Locust Street"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -75.20938329204654,
#                     39.949737338428804
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Clarkville",
#                 "address_line2": "4301 Baltimore Avenue, Philadelphia, PA 19104, United States of America",
#                 "categories": [
#                     "building",
#                     "building.catering",
#                     "catering",
#                     "catering.restaurant",
#                     "catering.restaurant.pizza",
#                     "vegan",
#                     "vegetarian"
#                 ],
#                 "city": "Philadelphia",
#                 "country": "United States",
#                 "country_code": "us",
#                 "county": "Philadelphia County",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:city": "Philadelphia",
#                         "addr:housenumber": 4301,
#                         "addr:postcode": 19104,
#                         "addr:state": "PA",
#                         "addr:street": "Baltimore Ave",
#                         "amenity": "restaurant",
#                         "building": "yes",
#                         "cuisine": "pizza",
#                         "diet:vegan": "yes",
#                         "diet:vegetarian": "yes",
#                         "name": "Clarkville",
#                         "opening_hours": "12:00-20:00",
#                         "osm_id": 200002962,
#                         "osm_type": "w",
#                         "phone": "+1 215-387-4992",
#                         "website": "https://clarkvillephilly.com/"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.catering",
#                     "details.contact"
#                 ],
#                 "district": "Southwest Schuylkill",
#                 "formatted": "Clarkville, 4301 Baltimore Avenue, Philadelphia, PA 19104, United States of America",
#                 "housenumber": "4301",
#                 "lat": 39.9497368,
#                 "lon": -75.20938321649061,
#                 "name": "Clarkville",
#                 "place_id": "51ccea2d8966cd52c059c02b3cfe90f94340f00102f90192cdeb0b0000000092030a436c61726b76696c6c65",
#                 "postcode": "19104",
#                 "state": "Pennsylvania",
#                 "state_code": "PA",
#                 "street": "Baltimore Avenue"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -75.2021435326295,
#                     39.95432114487178
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Hummus Grill",
#                 "address_line2": "3931 Walnut Street, Philadelphia, PA 19104, United States of America",
#                 "categories": [
#                     "building",
#                     "building.catering",
#                     "catering",
#                     "catering.restaurant",
#                     "catering.restaurant.mediterranean"
#                 ],
#                 "city": "Philadelphia",
#                 "country": "United States",
#                 "country_code": "us",
#                 "county": "Philadelphia County",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:city": "Philadelphia",
#                         "addr:housenumber": 3931,
#                         "addr:postcode": 19104,
#                         "addr:state": "PA",
#                         "addr:street": "Walnut Street",
#                         "amenity": "restaurant",
#                         "building": "yes",
#                         "cuisine": "mediterranean",
#                         "name": "Hummus Grill",
#                         "opening_hours": "Mo-Fr 11:00-20:45; Sa 11:00-19:45; Su 12:00-20:45",
#                         "osm_id": 200676626,
#                         "osm_type": "w",
#                         "phone": "+1-215-222-5300",
#                         "website": "https://www.hummusrestaurant.com/"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.catering",
#                     "details.contact"
#                 ],
#                 "formatted": "Hummus Grill, 3931 Walnut Street, Philadelphia, PA 19104, United States of America",
#                 "housenumber": "3931",
#                 "lat": 39.9543369,
#                 "lon": -75.2021419148756,
#                 "name": "Hummus Grill",
#                 "place_id": "51776f6debefcc52c059838dfd3127fa4340f00102f9011215f60b0000000092030c48756d6d7573204772696c6c",
#                 "postcode": "19104",
#                 "state": "Pennsylvania",
#                 "state_code": "PA",
#                 "street": "Walnut Street"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -75.09967066897543,
#                     40.02902288772042
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Chick-fil-A",
#                 "address_line2": "4670 Roosevelt Boulevard, Philadelphia, PA 19124, United States of America",
#                 "categories": [
#                     "building",
#                     "building.catering",
#                     "catering",
#                     "catering.fast_food"
#                 ],
#                 "city": "Philadelphia",
#                 "country": "United States",
#                 "country_code": "us",
#                 "county": "Philadelphia County",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:city": "Philadelphia",
#                         "addr:housenumber": 4670,
#                         "addr:postcode": 19124,
#                         "addr:state": "PA",
#                         "addr:street": "Roosevelt Boulevard",
#                         "amenity": "fast_food",
#                         "brand": "Chick-fil-A",
#                         "brand:wikidata": "Q491516",
#                         "brand:wikipedia": "en:Chick-fil-A",
#                         "building": "yes",
#                         "cuisine": "chicken",
#                         "drive_through": "yes",
#                         "name": "Chick-fil-A",
#                         "opening_hours": "Mo-Sa 06:30-22:00",
#                         "osm_id": 210856703,
#                         "osm_type": "w",
#                         "phone": "+12155350352",
#                         "takeaway": "yes",
#                         "website": "https://www.chick-fil-a.com/locations/pa/northeast-tower"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.catering",
#                     "details.contact",
#                     "details.facilities"
#                 ],
#                 "district": "Cedar Grove",
#                 "formatted": "Chick-fil-A, 4670 Roosevelt Boulevard, Philadelphia, PA 19124, United States of America",
#                 "housenumber": "4670",
#                 "lat": 40.02901835,
#                 "lon": -75.09967946421719,
#                 "name": "Chick-fil-A",
#                 "place_id": "51ade7150161c652c0591fcca005b7034440f00102f901ff6a910c0000000092030b436869636b2d66696c2d41",
#                 "postcode": "19124",
#                 "state": "Pennsylvania",
#                 "state_code": "PA",
#                 "street": "Roosevelt Boulevard"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -75.16650034999998,
#                     39.95543595026125
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Capriccio",
#                 "address_line2": "110 North 16th Street, Philadelphia, PA 19102, United States of America",
#                 "categories": [
#                     "building",
#                     "building.catering",
#                     "catering",
#                     "catering.cafe",
#                     "catering.cafe.coffee",
#                     "catering.cafe.coffee_shop"
#                 ],
#                 "city": "Philadelphia",
#                 "country": "United States",
#                 "country_code": "us",
#                 "county": "Philadelphia County",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:city": "Philadelphia",
#                         "addr:housenumber": 110,
#                         "addr:postcode": 19102,
#                         "addr:street": "North 16th Street",
#                         "amenity": "cafe",
#                         "building": "yes",
#                         "building:levels": 1,
#                         "cuisine": "coffee_shop",
#                         "name": "Capriccio",
#                         "opening_hours": "Mo-Fr 06:30-19:00; Sa-Su 08:00-20:00",
#                         "osm_id": 239873161,
#                         "osm_type": "w",
#                         "phone": "+1 215 735 9797",
#                         "website": "https://www.capricciocafe.com/"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.building",
#                     "details.catering",
#                     "details.contact"
#                 ],
#                 "formatted": "Capriccio, 110 North 16th Street, Philadelphia, PA 19102, United States of America",
#                 "housenumber": "110",
#                 "lat": 39.95543595,
#                 "lon": -75.16650035,
#                 "name": "Capriccio",
#                 "place_id": "51708115f1a7ca52c059bae5a7b94bfa4340f00102f901892c4c0e0000000092030943617072696363696f",
#                 "postcode": "19102",
#                 "state": "Pennsylvania",
#                 "state_code": "PA",
#                 "street": "North 16th Street",
#                 "suburb": "Center City"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -75.14457503877111,
#                     39.94713237322507
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "City Tavern",
#                 "address_line2": "South 2nd Street, Philadelphia, PA 19106, United States of America",
#                 "categories": [
#                     "building",
#                     "building.catering",
#                     "building.historic",
#                     "building.tourism",
#                     "catering",
#                     "catering.restaurant",
#                     "tourism",
#                     "tourism.attraction",
#                     "tourism.sights"
#                 ],
#                 "city": "Philadelphia",
#                 "country": "United States",
#                 "country_code": "us",
#                 "county": "Philadelphia County",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "restaurant",
#                         "building": "yes",
#                         "historic": "building",
#                         "name": "City Tavern",
#                         "osm_id": 261314257,
#                         "osm_type": "w",
#                         "phone": "+1 215-413-1443",
#                         "tourism": "attraction",
#                         "website": "https://www.citytavern.com/",
#                         "wikidata": "Q2974580",
#                         "wikipedia": "en:City Tavern"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.contact",
#                     "details.wiki_and_media"
#                 ],
#                 "district": "Society Hill",
#                 "formatted": "City Tavern, South 2nd Street, Philadelphia, PA 19106, United States of America",
#                 "lat": 39.9471264,
#                 "lon": -75.14455590138334,
#                 "name": "City Tavern",
#                 "place_id": "51c0d5a9b740c952c05905fe33a23bf94340f00102f901d156930f0000000092030b436974792054617665726e",
#                 "postcode": "19106",
#                 "state": "Pennsylvania",
#                 "state_code": "PA",
#                 "street": "South 2nd Street",
#                 "suburb": "Center City"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -75.17148637534407,
#                     39.92727858579866
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "South Philadelphia Tap Room",
#                 "address_line2": "1509 Mifflin Street, Philadelphia, PA 19145, United States of America",
#                 "categories": [
#                     "building",
#                     "building.catering",
#                     "building.commercial",
#                     "catering",
#                     "catering.bar"
#                 ],
#                 "city": "Philadelphia",
#                 "country": "United States",
#                 "country_code": "us",
#                 "county": "Philadelphia County",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:city": "Philadelphia",
#                         "addr:housenumber": 1509,
#                         "addr:postcode": 19145,
#                         "addr:street": "Mifflin Street",
#                         "amenity": "bar",
#                         "atm": "yes",
#                         "building": "yes",
#                         "building:levels": 2,
#                         "cuisine": "gastropub",
#                         "food": "yes",
#                         "name": "South Philadelphia Tap Room",
#                         "opening_hours": "11:00-02:00",
#                         "osm_id": 269853604,
#                         "osm_type": "w",
#                         "outdoor_seating": "yes",
#                         "phone": "+1 215 271 7787",
#                         "website": "http://www.southphiladelphiataproom.com/index2.html"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.building",
#                     "details.catering",
#                     "details.contact",
#                     "details.facilities"
#                 ],
#                 "district": "Wharton",
#                 "formatted": "South Philadelphia Tap Room, 1509 Mifflin Street, Philadelphia, PA 19145, United States of America",
#                 "housenumber": "1509",
#                 "lat": 39.927239900000004,
#                 "lon": -75.17149747292171,
#                 "name": "South Philadelphia Tap Room",
#                 "place_id": "51fe73fda1f9ca52c059a8249010b1f64340f00102f901a4a315100000000092031b536f757468205068696c6164656c706869612054617020526f6f6d",
#                 "postcode": "19145",
#                 "state": "Pennsylvania",
#                 "state_code": "PA",
#                 "street": "Mifflin Street",
#                 "suburb": "South Philadelphia"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -75.12701519946164,
#                     39.97647497407387
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "ReAnimator Coffee",
#                 "address_line2": "1523 East Susquehanna Avenue, Philadelphia, PA 19125, United States of America",
#                 "categories": [
#                     "building",
#                     "building.catering",
#                     "catering",
#                     "catering.cafe",
#                     "internet_access"
#                 ],
#                 "city": "Philadelphia",
#                 "country": "United States",
#                 "country_code": "us",
#                 "county": "Philadelphia County",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:city": "Philadelphia",
#                         "addr:housenumber": 1523,
#                         "addr:postcode": 19125,
#                         "addr:street": "East Susquehanna Avenue",
#                         "amenity": "cafe",
#                         "building": "yes",
#                         "internet_access": "yes",
#                         "name": "ReAnimator Coffee",
#                         "opening_hours": "Mo-Fr 06:30-19:00; Sa-Su 08:00-19:00",
#                         "osm_id": 287693940,
#                         "osm_type": "w",
#                         "phone": "(215) 425-5805",
#                         "website": "https://www.reanimatorcoffee.com/"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.contact",
#                     "details.facilities"
#                 ],
#                 "district": "Fishtown",
#                 "formatted": "ReAnimator Coffee, 1523 East Susquehanna Avenue, Philadelphia, PA 19125, United States of America",
#                 "housenumber": "1523",
#                 "lat": 39.97649555,
#                 "lon": -75.1270346427051,
#                 "name": "ReAnimator Coffee",
#                 "place_id": "5117f25b0421c852c0593e81c721fdfc4340f00102f90174dc2511000000009203115265416e696d61746f7220436f66666565",
#                 "postcode": "19125",
#                 "state": "Pennsylvania",
#                 "state_code": "PA",
#                 "street": "East Susquehanna Avenue"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -75.15837334999999,
#                     39.95055630026057
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Paulies Pizza",
#                 "address_line2": "31 South 11th Street, Philadelphia, PA 19107, United States of America",
#                 "categories": [
#                     "building",
#                     "building.catering",
#                     "catering",
#                     "catering.restaurant",
#                     "catering.restaurant.pizza"
#                 ],
#                 "city": "Philadelphia",
#                 "country": "United States",
#                 "country_code": "us",
#                 "county": "Philadelphia County",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:city": "Philadelphia",
#                         "addr:housenumber": 31,
#                         "addr:postcode": 19107,
#                         "addr:state": "PA",
#                         "addr:street": "South 11th Street",
#                         "amenity": "restaurant",
#                         "building": "yes",
#                         "building:levels": 4,
#                         "capacity": 30,
#                         "cuisine": "pizza",
#                         "delivery": "yes",
#                         "level": 4,
#                         "name": "Paulies Pizza",
#                         "opening_hours": "Mo-Th 10:00-24:00; Fr-Sa 10:00-04:00; Su 11:00-23:00",
#                         "osm_id": 333012738,
#                         "osm_type": "w",
#                         "outdoor_seating": "no",
#                         "phone": "+1-215-592-4715",
#                         "smoking": "no",
#                         "takeaway": "yes",
#                         "website": "https://www.pauliespizzaphiladelphia.com/"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.building",
#                     "details.catering",
#                     "details.contact",
#                     "details.facilities"
#                 ],
#                 "district": "Gayborhood",
#                 "formatted": "Paulies Pizza, 31 South 11th Street, Philadelphia, PA 19107, United States of America",
#                 "housenumber": "31",
#                 "lat": 39.9505563,
#                 "lon": -75.15837335,
#                 "name": "Paulies Pizza",
#                 "place_id": "51b5b3f9c922ca52c0591e502fd4abf94340f00102f901025fd9130000000092030d5061756c6965732050697a7a61",
#                 "postcode": "19107",
#                 "state": "Pennsylvania",
#                 "state_code": "PA",
#                 "street": "South 11th Street",
#                 "suburb": "Center City"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -75.17074175311855,
#                     39.95101507619146
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "The Dandelion",
#                 "address_line2": "124 South 18th Street, Philadelphia, PA 19103, United States of America",
#                 "categories": [
#                     "building",
#                     "building.catering",
#                     "catering",
#                     "catering.pub"
#                 ],
#                 "city": "Philadelphia",
#                 "country": "United States",
#                 "country_code": "us",
#                 "county": "Philadelphia County",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:city": "Philadelphia",
#                         "addr:housenumber": 124,
#                         "addr:postcode": 19103,
#                         "addr:street": "South 18th Street",
#                         "air_conditioning": "yes",
#                         "amenity": "pub",
#                         "building": "yes",
#                         "building:levels": 3,
#                         "email": "thedandelion.info@starr-restaurants.com",
#                         "name": "The Dandelion",
#                         "opening_hours": "Mo-Th 11:30-23:00; Fr 11:30-00:00; Sa 10:00-00:00; Su 10:00-22:00",
#                         "osm_id": 336505649,
#                         "osm_type": "w",
#                         "phone": "+1 215 558 2500",
#                         "roof:levels": 1,
#                         "smoking": "no",
#                         "toilets": "yes",
#                         "website": "https://thedandelionpub.com/"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.building",
#                     "details.contact",
#                     "details.facilities"
#                 ],
#                 "district": "Rittenhouse Square",
#                 "formatted": "The Dandelion, 124 South 18th Street, Philadelphia, PA 19103, United States of America",
#                 "housenumber": "124",
#                 "lat": 39.95101485,
#                 "lon": -75.17074136802594,
#                 "name": "The Dandelion",
#                 "place_id": "512d6dd16eedca52c059651faddcbaf94340f00102f90131ab0e140000000092030d5468652044616e64656c696f6e",
#                 "postcode": "19103",
#                 "state": "Pennsylvania",
#                 "state_code": "PA",
#                 "street": "South 18th Street",
#                 "suburb": "Center City"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -75.19252357223019,
#                     39.95349006930155
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Avril 50",
#                 "address_line2": "3406 Sansom Street, Philadelphia, PA 19104, United States of America",
#                 "categories": [
#                     "building",
#                     "building.catering",
#                     "building.commercial",
#                     "catering",
#                     "catering.cafe",
#                     "catering.cafe.coffee",
#                     "catering.cafe.coffee_shop",
#                     "commercial"
#                 ],
#                 "city": "Philadelphia",
#                 "country": "United States",
#                 "country_code": "us",
#                 "county": "Philadelphia County",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:city": "Philadelphia",
#                         "addr:country": "US",
#                         "addr:housenumber": 3406,
#                         "addr:postcode": 19104,
#                         "addr:state": "PA",
#                         "addr:street": "Sansom Street",
#                         "amenity": "cafe",
#                         "building": "yes",
#                         "cuisine": "coffee_shop",
#                         "description": "International publications fine cards, gourmet coffee, tea, chocolate &#38;#38; tobacco",
#                         "drink:club-mate": "retail",
#                         "email": "info@avril50.com",
#                         "name": "Avril 50",
#                         "opening_hours": "Mo-Fr 07:30-18:00; Sa 10:00-17:00",
#                         "osm_id": 369570963,
#                         "osm_type": "w",
#                         "outdoor_seating": "yes",
#                         "phone": "+1-215-222-6108",
#                         "shop": "coffee;cards;chocolate;tobacco;tea;magazines",
#                         "website": "http://avril50.com/"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.catering",
#                     "details.contact",
#                     "details.facilities"
#                 ],
#                 "district": "University City",
#                 "formatted": "Avril 50, 3406 Sansom Street, Philadelphia, PA 19104, United States of America",
#                 "housenumber": "3406",
#                 "lat": 39.9534493,
#                 "lon": -75.19253512569071,
#                 "name": "Avril 50",
#                 "place_id": "51049c634e52cc52c059005b6cf60bfa4340f00102f9019334071600000000920308417672696c203530",
#                 "postcode": "19104",
#                 "state": "Pennsylvania",
#                 "state_code": "PA",
#                 "street": "Sansom Street"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -75.19296599999998,
#                     39.953562150261
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "White Dog Cafe",
#                 "address_line2": "3420 Sansom Street, Philadelphia, PA 19104, United States of America",
#                 "categories": [
#                     "building",
#                     "building.catering",
#                     "building.commercial",
#                     "catering",
#                     "catering.restaurant"
#                 ],
#                 "city": "Philadelphia",
#                 "country": "United States",
#                 "country_code": "us",
#                 "county": "Philadelphia County",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:city": "Philadelphia",
#                         "addr:country": "US",
#                         "addr:housenumber": 3420,
#                         "addr:postcode": 19104,
#                         "addr:state": "PA",
#                         "addr:street": "Sansom Street",
#                         "amenity": "restaurant",
#                         "building": "commercial",
#                         "email": "universitycity@whitedog.com",
#                         "name": "White Dog Cafe",
#                         "opening_hours": "Mo-Fr 11:00-14:30; Sa-Su 09:30-14:30; Mo-Su 14:30-17:00; Mo-Th 17:00-21:30; Fr-Sa 17:00-22:00; Su 17:00-21:00",
#                         "osm_id": 369570967,
#                         "osm_type": "w",
#                         "phone": "+1-215-386-9224",
#                         "website": "https://www.whitedog.com/"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.contact"
#                 ],
#                 "district": "University City",
#                 "formatted": "White Dog Cafe, 3420 Sansom Street, Philadelphia, PA 19104, United States of America",
#                 "housenumber": "3420",
#                 "lat": 39.953562149999996,
#                 "lon": -75.192966,
#                 "name": "White Dog Cafe",
#                 "place_id": "515acf108e59cc52c059870915530efa4340f00102f901973407160000000092030e576869746520446f672043616665",
#                 "postcode": "19104",
#                 "state": "Pennsylvania",
#                 "state_code": "PA",
#                 "street": "Sansom Street"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -75.07339356159393,
#                     39.99749875123103
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Old English Pizzeria",
#                 "address_line2": "2765 Orthodox Street, Philadelphia, PA 19137, United States of America",
#                 "categories": [
#                     "building",
#                     "building.catering",
#                     "catering",
#                     "catering.restaurant",
#                     "catering.restaurant.american",
#                     "wheelchair",
#                     "wheelchair.yes"
#                 ],
#                 "city": "Philadelphia",
#                 "country": "United States",
#                 "country_code": "us",
#                 "county": "Philadelphia County",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:city": "Philadelphia",
#                         "addr:country": "US",
#                         "addr:housenumber": 2765,
#                         "addr:postcode": 19137,
#                         "addr:state": "PA",
#                         "addr:street": "Orthodox Street",
#                         "amenity": "restaurant",
#                         "building": "yes",
#                         "cuisine": "american",
#                         "delivery": "yes",
#                         "name": "Old English Pizzeria",
#                         "opening_hours": "Mo-Sa 11:00-01:00, Su 11:00-23:00",
#                         "osm_id": 374115857,
#                         "osm_type": "w",
#                         "phone": "(215) 288-9900",
#                         "smoking": "no",
#                         "takeaway": "yes",
#                         "website": "https://philadelphia.menupages.com/restaurants/old-english-pizza/menu",
#                         "wheelchair": "yes"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.catering",
#                     "details.contact",
#                     "details.facilities"
#                 ],
#                 "district": "Bridesburg",
#                 "formatted": "Old English Pizzeria, 2765 Orthodox Street, Philadelphia, PA 19137, United States of America",
#                 "housenumber": "2765",
#                 "lat": 39.99750085,
#                 "lon": -75.07339132297155,
#                 "name": "Old English Pizzeria",
#                 "place_id": "511bb2e87ab2c452c059472b010aaeff4340f00102f901118e4c16000000009203144f6c6420456e676c6973682050697a7a65726961",
#                 "postcode": "19137",
#                 "state": "Pennsylvania",
#                 "state_code": "PA",
#                 "street": "Orthodox Street"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -75.23287285080215,
#                     40.08343105491131
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "The Cedars House",
#                 "address_line2": "Forbidden Drive, Philadelphia, PA 19128, United States of America",
#                 "categories": [
#                     "building",
#                     "building.catering",
#                     "catering",
#                     "catering.cafe"
#                 ],
#                 "city": "Philadelphia",
#                 "country": "United States",
#                 "country_code": "us",
#                 "county": "Philadelphia County",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "amenity": "cafe",
#                         "building": "yes",
#                         "name": "The Cedars House",
#                         "opening_hours": "08:00-15:00",
#                         "osm_id": 420873512,
#                         "osm_type": "w",
#                         "outdoor_seating": "yes",
#                         "website": "https://thecedarshouse.com/",
#                         "wikidata": "Q114615434"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.catering",
#                     "details.facilities",
#                     "details.wiki_and_media"
#                 ],
#                 "formatted": "The Cedars House, Forbidden Drive, Philadelphia, PA 19128, United States of America",
#                 "lat": 40.083422850000005,
#                 "lon": -75.23286875,
#                 "name": "The Cedars House",
#                 "place_id": "5194948763e7ce52c0594d286adead0a4440f00102f90128051619000000009203105468652043656461727320486f757365",
#                 "postcode": "19128",
#                 "state": "Pennsylvania",
#                 "state_code": "PA",
#                 "street": "Forbidden Drive"
#             },
#             "type": "Feature"
#         },
#         {
#             "geometry": {
#                 "coordinates": [
#                     -75.17173740585312,
#                     39.924854022646436
#                 ],
#                 "type": "Point"
#             },
#             "properties": {
#                 "address_line1": "Melrose Diner",
#                 "address_line2": "1501 Snyder Avenue, Philadelphia, PA 19145, United States of America",
#                 "categories": [
#                     "building",
#                     "building.catering",
#                     "catering",
#                     "catering.restaurant"
#                 ],
#                 "city": "Philadelphia",
#                 "country": "United States",
#                 "country_code": "us",
#                 "county": "Philadelphia County",
#                 "datasource": {
#                     "attribution": "\u00a9 OpenStreetMap contributors",
#                     "license": "Open Database Licence",
#                     "raw": {
#                         "addr:city": "Philadelphia",
#                         "addr:housenumber": 1501,
#                         "addr:postcode": 19145,
#                         "addr:state": "PA",
#                         "addr:street": "Snyder Avenue",
#                         "amenity": "restaurant",
#                         "building": "yes",
#                         "name": "Melrose Diner",
#                         "opening_hours": "24/7",
#                         "osm_id": 438545000,
#                         "osm_type": "w",
#                         "phone": "+1 215 467 6644",
#                         "takeaway": "yes",
#                         "website": "https://www.themelrosedinerandbakery.com/"
#                     },
#                     "sourcename": "openstreetmap",
#                     "url": "https://www.openstreetmap.org/copyright"
#                 },
#                 "details": [
#                     "details",
#                     "details.catering",
#                     "details.contact",
#                     "details.facilities"
#                 ],
#                 "formatted": "Melrose Diner, 1501 Snyder Avenue, Philadelphia, PA 19145, United States of America",
#                 "housenumber": "1501",
#                 "lat": 39.92486685,
#                 "lon": -75.17176139055883,
#                 "name": "Melrose Diner",
#                 "place_id": "51e668e3befdca52c059956bda9d61f64340f00102f90168aa231a0000000092030d4d656c726f73652044696e6572",
#                 "postcode": "19145",
#                 "state": "Pennsylvania",
#                 "state_code": "PA",
#                 "street": "Snyder Avenue",
#                 "suburb": "South Philadelphia"
#             },
#             "type": "Feature"
#         }
#     ],
#     "type": "FeatureCollection"
# }

# %%
counter = 0

for place in response["features"]:
    print(f"Restaurant {counter+1}:")
    print(place["properties"]["name"])
    print(place["properties"]["address_line2"])
    print("*"*20)
    counter = counter + 1
    if counter == 5:
        break
# Out:
# Restaurant 1:
# Valley Green Inn
# Valley Green Road, Philadelphia, PA 19128, United States of America
# ********************
# Restaurant 2:
# Geno's Steaks
# 1219 South 9th Street, Philadelphia, PA 19147, United States of America
# ********************
# Restaurant 3:
# McDonald's
# 3935 Walnut Street, Philadelphia, PA 19104, United States of America
# ********************
# Restaurant 4:
# Moshulu
# South Christopher Columbus Boulevard, Philadelphia, PA 19106, United States of America
# ********************
# Restaurant 5:
# Green Line Cafe
# 4239 Baltimore Avenue, Philadelphia, PA 19104, United States of America
# ********************

# %%
print(response["features"][0]["properties"]["name"])
print(response["features"][0]["properties"]["address_line2"])
# Out:
# Valley Green Inn
# Valley Green Road, Philadelphia, PA 19128, United States of America

# %%
lat = response["features"][0]["properties"]["lat"]
lon = response["features"][0]["properties"]["lon"]

# Print results
print(f"{target_city}: {lat}, {lon}")
# Out:
# Philadelphia, Pennsylvania: 40.05408665, -75.21821459327312

# %%
# Set the geographical coordinates
latitude = 40.05408665
longitude = -75.21821459327312

# Set the parameters for the type of search
limit = 20
radius = 1000
filters = f"circle:{longitude},{latitude},{radius}"
bias = f"proximity:{longitude},{latitude}"

# set up a parameters dictionary
params = {
    "filter":filters,
    "limit":limit,
    "bias":bias,
    "geoapify_key":geoapify_key    
}

# Set base URL
target_url = "https://api.geoapify.com/v2/places"
